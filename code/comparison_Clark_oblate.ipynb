# %% [markdown]
# # Comparison between different algorithms for calculating the magnetic field produced by elipsoids

# %% [markdown]
# The magnetic induction field produced by elipsoids can be calculated by different algorithms, depending on the shape of the elipsoid. Emerson (1985) proposed algorithms for calculating the magnetic field produced by prolate and oblates elipsoids. Clark (1986) bla bla bla
#
# This code compares the magnetic field produced by bla bla bla
#
#
# * Reference 1
# * Reference 2

# %% [markdown]
# ### Required dependencies

# %%
import numpy as np
from scipy import linalg
from matplotlib import pyplot as plt

from fatiando.gravmag import sphere
from fatiando import mesher, gridder, utils
from fatiando.vis import mpl

# %matplotlib inline

# %% [markdown]
# ### Auxiliary functions

# %%
import Elipsoide_Clark_FAT as me
import Modelagem_Elipsoide_Emerson_Oblato as me2

# %% [markdown]
# ### Computation points

# %%
# Malha coordenadas geograficas
xmin = -100.
xmax = 100.
ymin = -90.
ymax = 90.
Nx = 200
Ny = 200

# %%
# Create a regular grid at 0m height
shape = (Nx, Ny)
area = [xmin, xmax, ymin, ymax]
Xp, Yp, Zp = gridder.regular(area, shape, z=0.)

# %% [markdown]
# ### Geomagnetic field

# %%
# Set the inclination and declination of the regional field
inten, inc, dec  = 60000., np.deg2rad(90.), np.deg2rad(0.)

# %% [markdown]
# ### Center of the elipsoid

# %%
#xc posicao x , yc posição y e zc profundidade reais
xc = 0.
yc = 0.
zc = 100.

# %% [markdown]
# ### Remanent magnetization and susceptibility tensor

# %%
#vetor magnetização remanente
intensidade = 10000.
inclinacao = np.deg2rad(90.)
declinacao = np.deg2rad(0.)

#vetor de susceptibilidades
intensidadeA = 0.1
inclinacaoA = np.deg2rad(90.)
declinacaoA = np.deg2rad(0.)
intensidadeB = 0.1
inclinacaoB = np.deg2rad(180.)
declinacaoB = np.deg2rad(0.)
intensidadeC = 0.1
inclinacaoC = np.deg2rad(0.)
declinacaoC = np.deg2rad(90.)
k_int = np.array([[intensidadeA],
                  [intensidadeB],
                  [intensidadeC]])
k_inc = np.array([[inclinacaoA],
                  [inclinacaoB],
                  [inclinacaoC]])
k_dec = np.array([[declinacaoA],
                  [declinacaoB],
                  [declinacaoC]])

# %% [markdown]
# ### Elipsoid orientation

# %%
# Orientacoes do elipsoide
azimute = 0.
alfa = np.deg2rad(azimute+180.)
delta = np.deg2rad(0.)
gamma = np.deg2rad(0.)

# %% [markdown]
# ### Reference axis and axis difference

# %%
daxis = 0.01
aref = 5.

# %% [markdown]
# # Fatiando a Terra - Ellipsoid Clark

# %%
# Ellipsoid axis
a = aref + daxis
b = aref
c = aref - daxis

################################################################################################################################

# Create a ellipsoid model
model = [me.Ellipsoid(xc, yc, zc, a, b, c, alfa, delta, gamma, {'remanence': np.array([10000, np.deg2rad(90.), np.deg2rad(0.)]),
                                                            'k1': np.array([(0.1), np.deg2rad(90.), np.deg2rad(0.)]),
                                                            'k2': np.array([(0.1), np.deg2rad(180.), np.deg2rad(0.)]),
                                                            'k3': np.array([(0.1), np.deg2rad(0.), np.deg2rad(90.)])})]

# Calculate the anomaly for a given regional field
Bx = me.bx_c (Xp,Yp,Zp,inten,inc,dec,model)
By = me.by_c (Xp,Yp,Zp,inten,inc,dec,model)
Bz = me.bz_c (Xp,Yp,Zp,inten,inc,dec,model)
Tf,jrd_ang = me.tf_c (Xp,Yp,Zp,inten,inc,dec,model)
print jrd_ang
# Out:
# [13802.636087458401, 90.0, 3.9350732698437098e-16]

# %% [markdown]
# # Implementation  - Ellipsoid Emerson Oblate

# %%
# Ellipsoid axis
b = aref + daxis
a = aref - daxis

# Orientacoes do elipsoide
azimute = 0.
alfa = np.deg2rad(azimute+180.)
delta = np.deg2rad(0.)

#Construção matriz de susceptibilidades k
l1 = me2.l1_v (alfa, delta)
l2 = me2.l2_v (alfa, delta)
l3 = me2.l3_v (alfa, delta)    
m1 = me2.m1_v (alfa, delta)
m2 = me2.m2_v (alfa, delta)
m3 = me2.m3_v (alfa, delta)    
n1 = me2.n1_v (delta)
n2 = me2.n2_v (delta)
n3 = me2.n3_v (delta)
Lr = me2.Lr_v (k_dec, k_inc)
Mr = me2.Mr_v (k_dec, k_inc)
Nr = me2.Nr_v (k_inc)

if k_int[0] == k_int[1] and k_int[0] == k_int[2]:
    km = me2.k_matrix2 (k_int,l1,l2,l3,m1,m2,m3,n1,n2,n3)
else:
    Lr = me2.Lr_v (k_dec, k_inc)
    Mr = me2.Mr_v (k_dec, k_inc)
    Nr = me2.Nr_v (k_inc)
    km = me2.k_matrix (k_int,Lr,Mr,Nr,l1,l2,l3,m1,m2,m3,n1,n2,n3)

Bx_O, By_O, Bz_O = me2.elipsoide (a,b,zc,alfa,delta,Xp,Yp,Zp,xc,yc,declinacao,inclinacao,intensidade,dec,inc,inten,km)

Tf_O = (Bx_O*np.cos(inc)*np.cos(dec) + By_O*np.cos(inc)*np.sin(dec) + Bz_O*np.sin(inc))
# Out:
# [11265.85863996562, array([ 90.]), array([ 0.])]

# %% [markdown]
# ## Resultado da minha função

# %%
rangesBx = np.max(np.abs([np.max(Bx), np.min(Bx),
                          np.max(Bx_O), np.min(Bx_O)]))

plt.figure(figsize=(15,8))

plt.subplot(1,2,1)
plt.title('Elipsoide Fatiando Clark', y=1.08)
plt.axis('scaled')
plt.tricontourf(Yp,Xp,Bx,15,
            vmin = -rangesBx, vmax = rangesBx,
            cmap=plt.cm.RdBu_r)
cb = plt.colorbar(shrink=0.7)
plt.xlim(ymin,ymax)
plt.ylim(xmin,xmax)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Coordenada horizontal y (m)', fontsize=14)
plt.ylabel('Coordenada horizontal x (m)', fontsize=14)

plt.subplot(1,2,2)
plt.title('Elipsoide Emerson Oblato', y=1.08)
plt.axis('scaled')
plt.tricontourf(Yp,Xp,Bx_O,15,
            vmin = -rangesBx, vmax = rangesBx,
            cmap=plt.cm.RdBu_r)
cb = plt.colorbar(shrink=0.7)
plt.xlim(ymin,ymax)
plt.ylim(xmin,xmax)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Coordenada horizontal y (m)', fontsize=14)
plt.ylabel('Coordenada horizontal x (m)', fontsize=14)

plt.tight_layout()

# %%
rangesBy = np.max(np.abs([np.max(By), np.min(By),
                          np.max(By_O), np.min(By_O)]))

plt.figure(figsize=(15,8))

plt.subplot(1,2,1)
plt.title('Elipsoide Fatiando Clark', y=1.08)
plt.axis('scaled')
plt.tricontourf(Yp,Xp,By,15,
            vmin = -rangesBy, vmax = rangesBy,
            cmap=plt.cm.RdBu_r)
cb = plt.colorbar(shrink=0.7)
plt.xlim(ymin,ymax)
plt.ylim(xmin,xmax)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Coordenada horizontal y (m)', fontsize=14)
plt.ylabel('Coordenada horizontal x (m)', fontsize=14)

plt.subplot(1,2,2)
plt.title('Elipsoide Emerson Oblato', y=1.08)
plt.axis('scaled')
plt.tricontourf(Yp,Xp,By_O,15,
            vmin = -rangesBy, vmax = rangesBy,
            cmap=plt.cm.RdBu_r)
cb = plt.colorbar(shrink=0.7)
plt.xlim(ymin,ymax)
plt.ylim(xmin,xmax)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Coordenada horizontal y (m)', fontsize=14)
plt.ylabel('Coordenada horizontal x (m)', fontsize=14)

plt.tight_layout()

# %%
rangesBz = np.max(np.abs([np.max(Bz), np.min(Bz),
                          np.max(Bz_O), np.min(Bz_O)]))

plt.figure(figsize=(15,8))

plt.subplot(1,2,1)
plt.title('Elipsoide Fatiando Clark', y=1.08)
plt.axis('scaled')
plt.tricontourf(Yp,Xp,Bz,15,
            vmin = -rangesBz, vmax = rangesBz,
            cmap=plt.cm.RdBu_r)
cb = plt.colorbar(shrink=0.7)
plt.xlim(ymin,ymax)
plt.ylim(xmin,xmax)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Coordenada horizontal y (m)', fontsize=14)
plt.ylabel('Coordenada horizontal x (m)', fontsize=14)

plt.subplot(1,2,2)
plt.title('Elipsoide Emerson Oblato', y=1.08)
plt.axis('scaled')
plt.tricontourf(Yp,Xp,Bz_O,15,
            vmin = -rangesBz, vmax = rangesBz,
            cmap=plt.cm.RdBu_r)
cb = plt.colorbar(shrink=0.7)
plt.xlim(ymin,ymax)
plt.ylim(xmin,xmax)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Coordenada horizontal y (m)', fontsize=14)
plt.ylabel('Coordenada horizontal x (m)', fontsize=14)

plt.tight_layout()

# %%
rangesTf = np.max(np.abs([np.max(Tf), np.min(Tf),
                          np.max(Tf_O), np.min(Tf_O)]))

plt.figure(figsize=(15,8))

plt.subplot(1,2,1)
plt.title('Elipsoide Fatiando Clark', y=1.08)
plt.axis('scaled')
plt.tricontourf(Yp,Xp,Tf,15,
            vmin = -rangesTf, vmax = rangesTf,
            cmap=plt.cm.RdBu_r)
cb = plt.colorbar(shrink=0.7)
plt.xlim(ymin,ymax)
plt.ylim(xmin,xmax)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Coordenada horizontal y (m)', fontsize=14)
plt.ylabel('Coordenada horizontal x (m)', fontsize=14)

plt.subplot(1,2,2)
plt.title('Elipsoide Emerson Oblato', y=1.08)
plt.axis('scaled')
plt.tricontourf(Yp,Xp,Tf_O,15,
            vmin = -rangesTf, vmax = rangesTf,
            cmap=plt.cm.RdBu_r)
cb = plt.colorbar(shrink=0.7)
plt.xlim(ymin,ymax)
plt.ylim(xmin,xmax)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Coordenada horizontal y (m)', fontsize=14)
plt.ylabel('Coordenada horizontal x (m)', fontsize=14)

plt.tight_layout()
